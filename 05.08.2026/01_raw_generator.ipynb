# %%
import pandas as pd
import numpy as np

# %%
shipment_ids = [5001, 5001, 5002, 5003, 5003, 5004]
cities = ["саратов ", "САРАТОВ", " москва", "Самара", "Самара", " москва"]
volumes = [120, 120, None, 450, 450, 310]

# %%
raw_data = {
    'shipment_id': shipment_ids,
    'city': cities,
    'volume': volumes
}
df = pd.DataFrame(raw_data)
df.to_csv('raw_shipments.csv', index=False, encoding='utf-8-sig')

df
# Out:
#    shipment_id      city  volume
# 0         5001  саратов    120.0
# 1         5001   САРАТОВ   120.0
# 2         5002    москва     NaN
# 3         5003    Самара   450.0
# 4         5003    Самара   450.0
# 5         5004    москва   310.0
